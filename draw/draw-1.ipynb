# %%
import matplotlib.pyplot as plt
figure=plt.figure()
axes=figure.add_subplot()
X=[1,2,3]
Y=[5,6,7]
axes.plot(X,Y,'bo')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
gay=plt.figure()
axes1=gay.add_subplot(1,3,1)
axes1.set_title('one')
axes2=gay.add_subplot(1,3,2)
axes2.set_title('two')
axes3=gay.add_subplot(1,3,3)
axes3.set_title('three')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
